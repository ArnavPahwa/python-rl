# %%
import pandas as pd 
df = pd.read_csv('C:\\Python-full\\python-main\\sales.csv')
df
# Out:
#         Unnamed: 0  Order ID                 Product  Quantity Ordered  \
# 0              0.0  295665.0      Macbook Pro Laptop               1.0
# 1              1.0  295666.0      LG Washing Machine               1.0
# 2              NaN       NaN                     NaN               NaN
# 3              NaN       NaN                     NaN               NaN
# 4              2.0  295667.0    USB-C Charging Cable               1.0
# ...            ...       ...                     ...               ...
# 185957     13617.0  222905.0  AAA Batteries (4-pack)               1.0
# 185958     13618.0  222906.0        27in FHD Monitor               1.0
# 185959     13619.0  222907.0    USB-C Charging Cable               1.0
# 185960     13620.0  222908.0    USB-C Charging Cable               1.0
# 185961     13621.0  222909.0  AAA Batteries (4-pack)               1.0
#
#         Price Each        Order Date                        Purchase Address
# ...

# %%
df = df.dropna(how= 'all')
df.reindex()
# Out:
#         Unnamed: 0  Order ID                 Product  Quantity Ordered  \
# 0              0.0  295665.0      Macbook Pro Laptop               1.0
# 1              1.0  295666.0      LG Washing Machine               1.0
# 4              2.0  295667.0    USB-C Charging Cable               1.0
# 5              3.0  295668.0        27in FHD Monitor               1.0
# 6              4.0  295669.0    USB-C Charging Cable               1.0
# ...            ...       ...                     ...               ...
# 185957     13617.0  222905.0  AAA Batteries (4-pack)               1.0
# 185958     13618.0  222906.0        27in FHD Monitor               1.0
# 185959     13619.0  222907.0    USB-C Charging Cable               1.0
# 185960     13620.0  222908.0    USB-C Charging Cable               1.0
# 185961     13621.0  222909.0  AAA Batteries (4-pack)               1.0
#
#         Price Each        Order Date                        Purchase Address
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
date = df['Order Date']

# %%
df.reindex()
# Out:
#         Unnamed: 0  Order ID                 Product  Quantity Ordered  \
# 0              0.0  295665.0      Macbook Pro Laptop               1.0
# 1              1.0  295666.0      LG Washing Machine               1.0
# 4              2.0  295667.0    USB-C Charging Cable               1.0
# 5              3.0  295668.0        27in FHD Monitor               1.0
# 6              4.0  295669.0    USB-C Charging Cable               1.0
# ...            ...       ...                     ...               ...
# 185957     13617.0  222905.0  AAA Batteries (4-pack)               1.0
# 185958     13618.0  222906.0        27in FHD Monitor               1.0
# 185959     13619.0  222907.0    USB-C Charging Cable               1.0
# 185960     13620.0  222908.0    USB-C Charging Cable               1.0
# 185961     13621.0  222909.0  AAA Batteries (4-pack)               1.0
#
#         Price Each        Order Date                        Purchase Address
# ...

# %%
r = 0
l1 = []
for x in date:
    try:
        l = []
        y = x.split()
        z = y[0]
        z = str(z)
        for xx in z:
            l.append(xx)
        xy = l[3]+l[4]
        l1.append(xy)

            
                
    except:
        print()
df['months'] = l1
df
# Out:
# ['12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '12', '
# ...

# %%
qty = df['Quantity Ordered']
pr = df['Price Each']
df['sale'] = (pr*qty)
df
# Out:
# C:\Users\arnav\AppData\Local\Temp\ipykernel_19480\2888176439.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sale'] = (pr*qty)
#         Unnamed: 0  Order ID                 Product  Quantity Ordered  \
# 0              0.0  295665.0      Macbook Pro Laptop               1.0
# 1              1.0  295666.0      LG Washing Machine               1.0
# 4              2.0  295667.0    USB-C Charging Cable               1.0
# 5              3.0  295668.0        27in FHD Monitor               1.0
# 6              4.0  295669.0    USB-C Charging Cable               1.0
# ...            ...       ...                     ...               ...
# 185957     13617.0  222905.0  AAA Batteries (4-pack)               1.0
# ...

# %%
df.sort_values(by=['sale'],ascending= False)
df
# Out:
#         Unnamed: 0  Order ID                 Product  Quantity Ordered  \
# 0              0.0  295665.0      Macbook Pro Laptop               1.0
# 1              1.0  295666.0      LG Washing Machine               1.0
# 4              2.0  295667.0    USB-C Charging Cable               1.0
# 5              3.0  295668.0        27in FHD Monitor               1.0
# 6              4.0  295669.0    USB-C Charging Cable               1.0
# ...            ...       ...                     ...               ...
# 185957     13617.0  222905.0  AAA Batteries (4-pack)               1.0
# 185958     13618.0  222906.0        27in FHD Monitor               1.0
# 185959     13619.0  222907.0    USB-C Charging Cable               1.0
# 185960     13620.0  222908.0    USB-C Charging Cable               1.0
# 185961     13621.0  222909.0  AAA Batteries (4-pack)               1.0
#
#         Price Each        Order Date                        Purchase Address  \
# ...

# %%
df.loc[df['Quantity Ordered'] > 3]
# Out:
#         Unnamed: 0  Order ID                 Product  Quantity Ordered  \
# 11             9.0  295674.0  AAA Batteries (4-pack)               4.0
# 24            22.0  295684.0  AAA Batteries (4-pack)               4.0
# 540          530.0  296167.0  AAA Batteries (4-pack)               4.0
# 553          543.0  296180.0   AA Batteries (4-pack)               4.0
# 591          581.0  296217.0   AA Batteries (4-pack)               4.0
# ...            ...       ...                     ...               ...
# 184079     11729.0  221110.0  AAA Batteries (4-pack)               4.0
# 184110     11760.0  221141.0  AAA Batteries (4-pack)               4.0
# 185585     13243.0  222549.0   AA Batteries (4-pack)               5.0
# 185713     13373.0  222674.0  AAA Batteries (4-pack)               4.0
# 185753     13413.0  222712.0  AAA Batteries (4-pack)               4.0
#
#         Price Each        Order Date                        Purchase Address  \
# ...
